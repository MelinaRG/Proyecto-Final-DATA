# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
#insercion dde datasets
df1=pd.read_csv("Datasets/olist_closed_deals_dataset.csv")
df2=pd.read_csv("Datasets/olist_customers_dataset.csv",dtype={"customer_zip_code_prefix": str})
df3=pd.read_csv("Datasets/olist_geolocation_dataset.csv",dtype={"geolocation_zip_code_prefix": str})
df4=pd.read_csv("Datasets/olist_marketing_qualified_leads_dataset.csv")
df5=pd.read_csv("Datasets/olist_order_items_dataset.csv")
df6=pd.read_csv("Datasets/olist_order_payments_dataset.csv")
df7=pd.read_csv("Datasets/olist_order_reviews_dataset.csv")
df8=pd.read_csv("Datasets/olist_orders_dataset.csv")
df9=pd.read_csv("Datasets/olist_products_dataset.csv")
df10=pd.read_csv("Datasets/olist_sellers_dataset.csv",dtype={"seller_zip_code_prefix": str})
df11=pd.read_csv("Datasets/product_category_name_translation.csv")

# %% [markdown]
# ## ETL olist_closed_deals_dataset

# %%
dfclosed=df1

# %%
dfclosed.head()
# Out:
#                              mql_id                         seller_id  \
# 0  5420aad7fec3549a85876ba1c529bd84  2c43fb513632d29b3b58df74816f1b06
# 1  a555fb36b9368110ede0f043dfc3b9a0  bbb7d7893a450660432ea6652310ebb7
# 2  327174d3648a2d047e8940d7d15204ca  612170e34b97004b3ba37eae81836b4c
# 3  f5fee8f7da74f4887f5bcae2bafb6dd6  21e1781e36faf92725dde4730a88ca0f
# 4  ffe640179b554e295c167a2f6be528e0  ed8cb7b190ceb6067227478e48cf8dde
#
#                              sdr_id                             sr_id  \
# 0  a8387c01a09e99ce014107505b92388c  4ef15afb4b2723d8f3d81e51ec7afefe
# 1  09285259593c61296eef10c734121d5b  d3d1e91a157ea7f90548eef82f1955e3
# 2  b90f87164b5f8c2cfa5c8572834dbe3f  6565aa9ce3178a5caf6171827af3a9ba
# 3  56bf83c4bb35763a51c2baab501b4c67  d3d1e91a157ea7f90548eef82f1955e3
# 4  4b339f9567d060bcea4f5136b9f5949e  d3d1e91a157ea7f90548eef82f1955e3
#
#               won_date business_segment      lead_type lead_behaviour_profile  \
# ...

# %%
dfclosed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842 entries, 0 to 841
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   mql_id                         842 non-null    object
#  1   seller_id                      842 non-null    object
#  2   sdr_id                         842 non-null    object
#  3   sr_id                          842 non-null    object
#  4   won_date                       842 non-null    object
#  5   business_segment               841 non-null    object
#  6   lead_type                      836 non-null    object
#  7   lead_behaviour_profile         665 non-null    object
#  8   has_company                    63 non-null     object
#  9   has_gtin                       64 non-null     object
#  10  average_stock                  66 non-null     object
#  11  business_type                  832 non-null    object
# ...

# %%
#Eliminamos columnas que no usaremos
dfclosed.drop(columns=["sdr_id","sr_id","lead_behaviour_profile","has_company","has_gtin","average_stock","business_type","declared_product_catalog_size","declared_monthly_revenue"],axis=1,inplace=True)

# %%
#Cambio el tipo de datetime
dfclosed["won_date"]=pd.to_datetime(dfclosed["won_date"],format="%Y-%m-%d %H:%M:%S")

# %%
dfclosed.isna().sum()
# Out:
# mql_id              0
# seller_id           0
# won_date            0
# business_segment    1
# lead_type           6
# dtype: int64

# %%
#Llenamos los vacios
dfclosed.fillna("SIN DATO",inplace=True)

# %%
dfclosed.head()
# Out:
#                              mql_id                         seller_id  \
# 0  5420aad7fec3549a85876ba1c529bd84  2c43fb513632d29b3b58df74816f1b06
# 1  a555fb36b9368110ede0f043dfc3b9a0  bbb7d7893a450660432ea6652310ebb7
# 2  327174d3648a2d047e8940d7d15204ca  612170e34b97004b3ba37eae81836b4c
# 3  f5fee8f7da74f4887f5bcae2bafb6dd6  21e1781e36faf92725dde4730a88ca0f
# 4  ffe640179b554e295c167a2f6be528e0  ed8cb7b190ceb6067227478e48cf8dde
#
#              won_date business_segment      lead_type
# 0 2018-02-26 19:58:54              pet  online_medium
# 1 2018-05-08 20:17:59  car_accessories       industry
# 2 2018-06-05 17:27:23  home_appliances     online_big
# 3 2018-01-17 13:51:03       food_drink   online_small
# 4 2018-07-03 20:17:45  home_appliances       industry

# %%
dfclosed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842 entries, 0 to 841
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   mql_id            842 non-null    object
#  1   seller_id         842 non-null    object
#  2   won_date          842 non-null    datetime64[ns]
#  3   business_segment  842 non-null    object
#  4   lead_type         842 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 33.0+ KB

# %%
#Exportamos el csv final
dfclosed.to_csv("datasetsout/olist_closed_deals_dataset.csv")

# %% [markdown]
# ## ETL olistcustomers_dataset

# %%
dfcostumers=df2

# %%
dfcostumers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#   customer_zip_code_prefix          customer_city customer_state
# 0                    14409                 franca             SP
# 1                    09790  sao bernardo do campo             SP
# 2                    01151              sao paulo             SP
# 3                    08775        mogi das cruzes             SP
# 4                    13056               campinas             SP

# %%
dfcostumers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  object
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: object(5)
# memory usage: 3.8+ MB

# %%
#Eliminamos las columnas que son redundantes
dfcostumers.drop(columns=["customer_city","customer_state"],axis=1,inplace=True)

# %%
dfcostumers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#   customer_zip_code_prefix
# 0                    14409
# 1                    09790
# 2                    01151
# 3                    08775
# 4                    13056

# %%
dfcostumers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  object
# dtypes: object(3)
# memory usage: 2.3+ MB

# %%
#Exportamos el csv final
dfcostumers.to_csv("datasetsout/olist_customers_dataset.csv")

# %% [markdown]
# ## ETL olist_geolocation_dataset

# %%
dfgeo=df3

# %%
dfgeo.head()
# Out:
#   geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                       01037       -23.545621       -46.639292
# 1                       01046       -23.546081       -46.644820
# 2                       01046       -23.546129       -46.642951
# 3                       01041       -23.544392       -46.639499
# 4                       01035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
dfgeo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  object
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 38.2+ MB

# %%
dfgeo.drop_duplicates(inplace=True)

# %%
dfgeo.head()
# Out:
#   geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                       01037       -23.545621       -46.639292
# 1                       01046       -23.546081       -46.644820
# 2                       01046       -23.546129       -46.642951
# 3                       01041       -23.544392       -46.639499
# 4                       01035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
dfgeo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 738332 entries, 0 to 1000161
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   geolocation_zip_code_prefix  738332 non-null  object
#  1   geolocation_lat              738332 non-null  float64
#  2   geolocation_lng              738332 non-null  float64
#  3   geolocation_city             738332 non-null  object
#  4   geolocation_state            738332 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 33.8+ MB

# %%
dfgeo.to_csv("datasetsout/olist_geolocation_dataset.csv")

# %% [markdown]
# ## ETL olist_marketing_qualified_leads_dataset

# %%
dfmarketing=df4

# %%
dfmarketing.head()
# Out:
#                              mql_id first_contact_date  \
# 0  dac32acd4db4c29c230538b72f8dd87d         2018-02-01
# 1  8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20
# 2  b4bc852d233dfefc5131f593b538befa         2018-03-22
# 3  6be030b81c75970747525b843c1ef4f8         2018-01-22
# 4  5420aad7fec3549a85876ba1c529bd84         2018-02-21
#
#                     landing_page_id          origin
# 0  88740e65d5d6b056e0cda098e1ea6313          social
# 1  007f9098284a86ee80ddeb25d53e0af8     paid_search
# 2  a7982125ff7aa3b2054c6e44f9d28522  organic_search
# 3  d45d558f0daeecf3cccdffe3c59684aa           email
# 4  b48ec5f3b04e9068441002a19df93c6c  organic_search

# %%
dfmarketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mql_id              8000 non-null   object
#  1   first_contact_date  8000 non-null   object
#  2   landing_page_id     8000 non-null   object
#  3   origin              7940 non-null   object
# dtypes: object(4)
# memory usage: 250.1+ KB

# %%
dfmarketing.drop(columns=["landing_page_id"],axis=1,inplace=True)

# %%
dfmarketing["first_contact_date"]=pd.to_datetime(dfmarketing["first_contact_date"],format="%Y-%m-%d %H:%M:%S")

# %%
dfmarketing.fillna("SIN DATO",inplace=True)

# %%
dfmarketing.head()
# Out:
#                              mql_id first_contact_date          origin
# 0  dac32acd4db4c29c230538b72f8dd87d         2018-02-01          social
# 1  8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20     paid_search
# 2  b4bc852d233dfefc5131f593b538befa         2018-03-22  organic_search
# 3  6be030b81c75970747525b843c1ef4f8         2018-01-22           email
# 4  5420aad7fec3549a85876ba1c529bd84         2018-02-21  organic_search

# %%
dfmarketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mql_id              8000 non-null   object
#  1   first_contact_date  8000 non-null   datetime64[ns]
#  2   origin              8000 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 187.6+ KB

# %%
dfmarketing.to_csv("datasetsout/olist_marketing_qualified_leads_dataset.csv")

# %% [markdown]
# ## ETL olist_order_items_dataset.csv

# %%
dfitems=df5

# %%
dfitems.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
dfitems.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
dfitems["shipping_limit_date"]=pd.to_datetime(dfitems["shipping_limit_date"],format="%Y-%m-%d %H:%M:%S")

# %%
dfitems.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %%
dfitems.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
dfitems.to_csv("datasetsout/olist_order_items_dataset.csv")

# %% [markdown]
# ## ETL olist_order_payments_dataset.csv

# %%
dfpayments=df6

# %%
dfpayments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
dfpayments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
#Solo para ver los precios y freight_value para un mismo order_id de las tablas payments y items
dfitems[dfitems["order_id"]=="03ecec245220b63fd7f68c1737ba99ba"]
# Out:
#                               order_id  order_item_id  \
# 1713  03ecec245220b63fd7f68c1737ba99ba              1
# 1714  03ecec245220b63fd7f68c1737ba99ba              2
#
#                             product_id                         seller_id  \
# 1713  d8cabd83757ecf48a7d2628dee9135c1  fe2032dab1a61af8794248c8196565c9
# 1714  059ca09d32720d9adce3ae12e181339d  620c87c171fb2a6dd6e8bb4dec959fc6
#
#      shipping_limit_date  price  freight_value
# 1713 2018-06-13 20:23:08  189.0          58.78
# 1714 2018-06-15 20:23:08  109.9          18.05

# %%
#Solo para ver el payment_value e para un mismo order_id de los dataframe dfpayments y dfitems
dfpayments[dfpayments["order_id"]=="03ecec245220b63fd7f68c1737ba99ba"]
# Out:
#                                order_id  payment_sequential payment_type  \
# 4151   03ecec245220b63fd7f68c1737ba99ba                   2      voucher
# 22318  03ecec245220b63fd7f68c1737ba99ba                   1  credit_card
#
#        payment_installments  payment_value
# 4151                      1          56.39
# 22318                     2         319.34

# %%
dftotalordercost=dfpayments.groupby(['order_id']).sum()

# %%
dftotalordercost=dftotalordercost.drop(columns=["payment_sequential","payment_installments"])

# %%
dftotalordercost.rename(columns={"payment_value":"TOTAL_ORDER_COST"},inplace=True)

# %%
#Para hacer join con la el dataframe dforder
dftotalordercost.head()
# Out:
#                                   TOTAL_ORDER_COST
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214             72.19
# 00018f77f2f0320c557190d7a144bdd3            259.83
# 000229ec398224ef6ca0657da4fc703e            216.87
# 00024acbcdf0a6daa1e931b038114c75             25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9            218.04

# %%
dfpayments.drop(columns="payment_sequential",inplace=True)

# %%
dfpayments.head()
# Out:
#                            order_id payment_type  payment_installments  \
# 0  b81ef226f3fe1789b1e8b2acac839d17  credit_card                     8
# 1  a9810da82917af2d9aefd1278f1dcfa0  credit_card                     1
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd  credit_card                     1
# 3  ba78997921bbcdc1373bb41e913ab953  credit_card                     8
# 4  42fdf880ba16b47b59251dd489d4441a  credit_card                     2
#
#    payment_value
# 0          99.33
# 1          24.39
# 2          65.71
# 3         107.78
# 4         128.45

# %%
dfpayments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 4 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_type          103886 non-null  object
#  2   payment_installments  103886 non-null  int64
#  3   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
dfpayments.to_csv("datasetsout/olist_order_payments_dataset.csv")

# %% [markdown]
# ## ETL olist_order_reviews_dataset

# %%
dfreviews=df7

# %%
dfreviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
dfreviews["review_creation_date"]=pd.to_datetime(dfreviews["review_creation_date"],format="%Y-%m-%d %H:%M:%S")

# %%
dfreviews["review_answer_timestamp"]=pd.to_datetime(dfreviews["review_answer_timestamp"],format="%Y-%m-%d %H:%M:%S")

# %%
dfreviews["review_comment_title"].fillna("SIN TITULO",inplace=True)
dfreviews["review_comment_message"].fillna("SIN COMENTARIOS",inplace=True)

# %%
dfreviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4           SIN TITULO
# 1             5           SIN TITULO
# 2             5           SIN TITULO
# 3             5           SIN TITULO
# 4             5           SIN TITULO
#
#                               review_comment_message review_creation_date  \
# 0                                    SIN COMENTARIOS           2018-01-18
# 1                                    SIN COMENTARIOS           2018-03-10
# 2                                    SIN COMENTARIOS           2018-02-17
# ...

# %%
dfreviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
dfreviews.to_csv("datasetsout/olist_order_reviews_dataset.csv")

# %% [markdown]
# ## ETL olist_orders_dataset

# %%
dforder=df8

# %%
dforder.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
dforder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
dforder["order_purchase_timestamp"]=pd.to_datetime(dforder["order_purchase_timestamp"],format="%Y-%m-%d %H:%M:%S")
dforder["order_approved_at"]=pd.to_datetime(dforder["order_approved_at"],format="%Y-%m-%d %H:%M:%S")
dforder["order_delivered_carrier_date"]=pd.to_datetime(dforder["order_delivered_carrier_date"],format="%Y-%m-%d %H:%M:%S")
dforder["order_delivered_customer_date"]=pd.to_datetime(dforder["order_delivered_customer_date"],format="%Y-%m-%d %H:%M:%S")
dforder["order_estimated_delivery_date"]=pd.to_datetime(dforder["order_estimated_delivery_date"],format="%Y-%m-%d %H:%M:%S")

# %%
dforder.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
#vemos diferencia entre que se aprueba la compra y en la que el cliente hace la compra
dforder['difference_days1'] = dforder['order_approved_at'] - dforder['order_purchase_timestamp']
#vemos diferencia entre es llevado al flete y en la que se aprueba la compra
dforder['difference_days2'] = dforder['order_delivered_carrier_date'] - dforder['order_approved_at']
#vemos diferencia entre que el producto llega al cliente y en la que se aprueba la compra
dforder['difference_days3'] = dforder['order_delivered_customer_date'] - dforder['order_approved_at']
#vemos diferencia entre que el producto llega al cliente y en la que se lleva al flete
dforder['difference_days4'] = dforder['order_delivered_customer_date'] - dforder['order_delivered_carrier_date']
#vemos diferencia entre la estimacion de la llegada del producto al clinte y el tiempo real en que llega el producto al cliente
dforder['difference_days5'] = dforder['order_estimated_delivery_date'] - dforder['order_delivered_customer_date']

# %%
#No hay problema entre los tiempos de order_approved_at y order_purchase_timestamp
dforder[dforder["difference_days1"]<pd.Timedelta(0)]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, difference_days1, difference_days2, difference_days3, difference_days4, difference_days5]
# Index: []

# %%
#1359 registros tienen problemas entre el tiempo de order_delivered_carrier_date y order_approved_at
dforder[dforder["difference_days2"]<pd.Timedelta(0)]
# Out:
#                                order_id                       customer_id  \
# 15     dcb36b511fcac050b97cd5c05de84dc3  3b6828a50ffe546942b7a473d70ac0fc
# 64     688052146432ef8253587b930b01a06d  81e08b08e5ed4472008030d70327c71f
# 199    58d4c4747ee059eeeb865b349b41f53a  1755fad7863475346bc6c3773fe055d3
# 210    412fccb2b44a99b36714bca3fef8ad7b  c6865c523687cb3f235aa599afef1710
# 415    56a4ac10a4a8f2ba7693523bb439eede  78438ba6ace7d2cb023dbbc81b083562
# ...                                 ...                               ...
# 99091  240ead1a7284667e0ec71d01f80e4d5e  fcdd7556401aaa1c980f8b67a69f95dc
# 99230  78008d03bd8ef7fcf1568728b316553c  043e3254e68daf7256bda1c9c03c2286
# 99266  76a948cd55bf22799753720d4545dd2d  3f20a07b28aa252d0502fe7f7eb030a9
# 99377  a6bd1f93b7ff72cc348ca07f38ec4bee  6d63fa86bd2f62908ad328325799152f
# 99406  7fd85cb0143de098a4c5ab5a57bfbd91  d32034dfc685b1ae15dd4c78eace868e
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
dforder[dforder["difference_days3"]<pd.Timedelta(0)]
# Out:
#                                order_id                       customer_id  \
# 199    58d4c4747ee059eeeb865b349b41f53a  1755fad7863475346bc6c3773fe055d3
# 483    4df92d82d79c3b52c7138679fa9b07fc  ba0660bf3fffe505ee892e153a2fbd49
# 1986   6e57e23ecac1ae881286657694444267  2dda54e25d0984e12705c84d4030e6e0
# 3659   f222c56f035b47dfa1e069a88235d730  b74ca180d63f9ae0443e4e13a2f5bdaf
# 11738  cf72398d0690f841271b695bbfda82d2  2b7fff075bda701552485ef3f0810257
# ...                                 ...                               ...
# 89703  fcbf4f4ef049367f9f85af94ed3b6010  814d433efda6ac4b0859b5a71aac64c8
# 91801  4387477eec4b3c89b39f3f454940d059  dbbbdb6ab9a7d8e3fc39a907f456bf19
# 93680  4f3a6e28d764cf896b1fceb0028422c8  e24fceba7ac4b1b1cd1884f05ba68e9d
# 94359  9c3186381b733d4304e2e416afc6bbc1  a4bd2fc7bf4fc0061011ef71a2208d63
# 98359  5a41aefdf8010bbd69a5264f69213b73  babb58dd58d643c769e12f18288b3214
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
#Sus errores solo se presetnan para diff4
dforder[dforder["difference_days4"]<pd.Timedelta(0)]
# Out:
#                                order_id                       customer_id  \
# 6437   a1abeb653a4d4cd1e142ccb8c82cd069  5f50465da00b7fed5dd1239f4ecf6e2c
# 9553   383aa8b2724fe452d9ccd9934a8c628b  b1cb2f9d7a19480f3749e248db14d58f
# 13487  cb1134f9010d242e9515ad1c78ec0c39  2fd33ac77677bd214b1882868317eeed
# 14474  dceb62e8fa94b46006c9554fed743df0  2721900eb4e0f1cc2c836dd7bc1b1e11
# 19268  5f9d46795c3126674e52becb3a1a517f  79287bcaafdde5c793b996fc40bb7d9f
# 21338  8c78d01de3a9009e23d6877a7cc9be20  6cd7106899e59a1fbd0622d5f1efedf4
# 22520  b27af682321527a6349f1761eb3f360c  9859dd92e872dbaa60ca3cd5f0d7ad07
# 25393  1cc3ae63caffff2d6c3ee3e78e074acf  01c843a2c0600def0b7693dba47af460
# 25646  e37f11cae9985ca58f0b56f268720537  3947a361301f2ff0f3223159a0f2701c
# 27470  fa3e37584f4fdb1ded0e0de700dfcb4e  63be4feff10a0b1d85f2cfbf10df9754
# 34939  c1e2bf2b7dd3309f2f5356c6b63968fa  e37d47e7eec62f08dc5deecc7d5532d6
# 41636  b866af202be0692766081310cd4085e1  d1800078046ed2e5ae1b0792b695c56e
# ...

# %%
dforder[(dforder["difference_days2"]<pd.Timedelta(0))& (dforder["difference_days3"]<pd.Timedelta(0))]
# Out:
#                                order_id                       customer_id  \
# 199    58d4c4747ee059eeeb865b349b41f53a  1755fad7863475346bc6c3773fe055d3
# 483    4df92d82d79c3b52c7138679fa9b07fc  ba0660bf3fffe505ee892e153a2fbd49
# 1986   6e57e23ecac1ae881286657694444267  2dda54e25d0984e12705c84d4030e6e0
# 3659   f222c56f035b47dfa1e069a88235d730  b74ca180d63f9ae0443e4e13a2f5bdaf
# 11738  cf72398d0690f841271b695bbfda82d2  2b7fff075bda701552485ef3f0810257
# ...                                 ...                               ...
# 89703  fcbf4f4ef049367f9f85af94ed3b6010  814d433efda6ac4b0859b5a71aac64c8
# 91801  4387477eec4b3c89b39f3f454940d059  dbbbdb6ab9a7d8e3fc39a907f456bf19
# 93680  4f3a6e28d764cf896b1fceb0028422c8  e24fceba7ac4b1b1cd1884f05ba68e9d
# 94359  9c3186381b733d4304e2e416afc6bbc1  a4bd2fc7bf4fc0061011ef71a2208d63
# 98359  5a41aefdf8010bbd69a5264f69213b73  babb58dd58d643c769e12f18288b3214
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
#Los problemas con diff 3 tb son parte de lso problemas con diff2 , por lo tanto se debe empezar de aca a corregir valors incongruentes
dforder[dforder["difference_days3"]<pd.Timedelta(0)]
# Out:
#                                order_id                       customer_id  \
# 199    58d4c4747ee059eeeb865b349b41f53a  1755fad7863475346bc6c3773fe055d3
# 483    4df92d82d79c3b52c7138679fa9b07fc  ba0660bf3fffe505ee892e153a2fbd49
# 1986   6e57e23ecac1ae881286657694444267  2dda54e25d0984e12705c84d4030e6e0
# 3659   f222c56f035b47dfa1e069a88235d730  b74ca180d63f9ae0443e4e13a2f5bdaf
# 11738  cf72398d0690f841271b695bbfda82d2  2b7fff075bda701552485ef3f0810257
# ...                                 ...                               ...
# 89703  fcbf4f4ef049367f9f85af94ed3b6010  814d433efda6ac4b0859b5a71aac64c8
# 91801  4387477eec4b3c89b39f3f454940d059  dbbbdb6ab9a7d8e3fc39a907f456bf19
# 93680  4f3a6e28d764cf896b1fceb0028422c8  e24fceba7ac4b1b1cd1884f05ba68e9d
# 94359  9c3186381b733d4304e2e416afc6bbc1  a4bd2fc7bf4fc0061011ef71a2208d63
# 98359  5a41aefdf8010bbd69a5264f69213b73  babb58dd58d643c769e12f18288b3214
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
#Nueva columna auxiliar para arregleas la columna order_approved_at_new que perfmita que diff3 tenga sentido
dforder["order_approved_at_new"]=dforder["order_purchase_timestamp"]+(dforder["order_delivered_carrier_date"]-dforder["order_purchase_timestamp"])/2

# %%
dforder.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
#Modifica la columa order_approved_at y arregla diff3
dforder.loc[(dforder["difference_days2"]<pd.Timedelta(0)) & (dforder["difference_days3"]<pd.Timedelta(0)),"order_approved_at"]=dforder.loc[(dforder["difference_days2"]<pd.Timedelta(0)) & (dforder["difference_days3"]<pd.Timedelta(0)),"order_approved_at_new"]

# %%
#vemos diferencia entre que se aprueba la compra y en la que el cliente hace la compra
dforder['difference_days1'] = dforder['order_approved_at'] - dforder['order_purchase_timestamp']
#vemos diferencia entre es llevado al flete y en la que se aprueba la compra
dforder['difference_days2'] = dforder['order_delivered_carrier_date'] - dforder['order_approved_at']
#vemos diferencia entre que el producto llega al cliente y en la que se aprueba la compra
dforder['difference_days3'] = dforder['order_delivered_customer_date'] - dforder['order_approved_at']
#vemos diferencia entre que el producto llega al cliente y en la que se lleva al flete
dforder['difference_days4'] = dforder['order_delivered_customer_date'] - dforder['order_delivered_carrier_date']
#vemos diferencia entre la estimacion de la llegada del producto al clinte y el tiempo real en que llega el producto al cliente
dforder['difference_days5'] = dforder['order_estimated_delivery_date'] - dforder['order_delivered_customer_date']

# %%
dforder[(dforder["difference_days2"]<pd.Timedelta(0))& (dforder["difference_days3"]<pd.Timedelta(0))]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, difference_days1, difference_days2, difference_days3, difference_days4, difference_days5, order_approved_at_new]
# Index: []

# %%
#1229 registros cuenta con problemas entre el tiempo de order_delivered_carrier_date y order_approved_at
dforder[(dforder["difference_days2"]<pd.Timedelta(0))]
# Out:
#                                order_id                       customer_id  \
# 15     dcb36b511fcac050b97cd5c05de84dc3  3b6828a50ffe546942b7a473d70ac0fc
# 64     688052146432ef8253587b930b01a06d  81e08b08e5ed4472008030d70327c71f
# 210    412fccb2b44a99b36714bca3fef8ad7b  c6865c523687cb3f235aa599afef1710
# 415    56a4ac10a4a8f2ba7693523bb439eede  78438ba6ace7d2cb023dbbc81b083562
# 481    32e4fa9bb468884309b58b9348de70c3  e54367d4b00c5cb76d2dfe71b9bdb89c
# ...                                 ...                               ...
# 99091  240ead1a7284667e0ec71d01f80e4d5e  fcdd7556401aaa1c980f8b67a69f95dc
# 99230  78008d03bd8ef7fcf1568728b316553c  043e3254e68daf7256bda1c9c03c2286
# 99266  76a948cd55bf22799753720d4545dd2d  3f20a07b28aa252d0502fe7f7eb030a9
# 99377  a6bd1f93b7ff72cc348ca07f38ec4bee  6d63fa86bd2f62908ad328325799152f
# 99406  7fd85cb0143de098a4c5ab5a57bfbd91  d32034dfc685b1ae15dd4c78eace868e
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
dforder["order_delivered_carrier_date_new"]=dforder["order_approved_at"]+(dforder["order_delivered_customer_date"]-dforder["order_approved_at"])/2

# %%
dforder.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
#Modifica la columa order_delivered_carrier_date y arregla diff2
dforder.loc[dforder["difference_days2"]<pd.Timedelta(0),"order_delivered_carrier_date"]=dforder.loc[dforder["difference_days2"]<pd.Timedelta(0),"order_delivered_carrier_date_new"]

# %%
dforder.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
#vemos diferencia entre que se aprueba la compra y en la que el cliente hace la compra
dforder['difference_days1'] = dforder['order_approved_at'] - dforder['order_purchase_timestamp']
#vemos diferencia entre es llevado al flete y en la que se aprueba la compra
dforder['difference_days2'] = dforder['order_delivered_carrier_date'] - dforder['order_approved_at']
#vemos diferencia entre que el producto llega al cliente y en la que se aprueba la compra
dforder['difference_days3'] = dforder['order_delivered_customer_date'] - dforder['order_approved_at']
#vemos diferencia entre que el producto llega al cliente y en la que se lleva al flete
dforder['difference_days4'] = dforder['order_delivered_customer_date'] - dforder['order_delivered_carrier_date']
#vemos diferencia entre la estimacion de la llegada del producto al cliente y el tiempo real en que llega el producto al cliente
dforder['difference_days5'] = dforder['order_estimated_delivery_date'] - dforder['order_delivered_customer_date']

# %%
dforder[dforder["difference_days2"]<pd.Timedelta(0)]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, difference_days1, difference_days2, difference_days3, difference_days4, difference_days5, order_approved_at_new, order_delivered_carrier_date_new]
# Index: []

# %%
dforder[dforder["difference_days3"]<pd.Timedelta(0)]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, difference_days1, difference_days2, difference_days3, difference_days4, difference_days5, order_approved_at_new, order_delivered_carrier_date_new]
# Index: []

# %%
dforder[dforder["difference_days4"]<pd.Timedelta(0)]
# Out:
#                                order_id                       customer_id  \
# 6437   a1abeb653a4d4cd1e142ccb8c82cd069  5f50465da00b7fed5dd1239f4ecf6e2c
# 9553   383aa8b2724fe452d9ccd9934a8c628b  b1cb2f9d7a19480f3749e248db14d58f
# 13487  cb1134f9010d242e9515ad1c78ec0c39  2fd33ac77677bd214b1882868317eeed
# 14474  dceb62e8fa94b46006c9554fed743df0  2721900eb4e0f1cc2c836dd7bc1b1e11
# 19268  5f9d46795c3126674e52becb3a1a517f  79287bcaafdde5c793b996fc40bb7d9f
# 21338  8c78d01de3a9009e23d6877a7cc9be20  6cd7106899e59a1fbd0622d5f1efedf4
# 22520  b27af682321527a6349f1761eb3f360c  9859dd92e872dbaa60ca3cd5f0d7ad07
# 25393  1cc3ae63caffff2d6c3ee3e78e074acf  01c843a2c0600def0b7693dba47af460
# 25646  e37f11cae9985ca58f0b56f268720537  3947a361301f2ff0f3223159a0f2701c
# 27470  fa3e37584f4fdb1ded0e0de700dfcb4e  63be4feff10a0b1d85f2cfbf10df9754
# 34939  c1e2bf2b7dd3309f2f5356c6b63968fa  e37d47e7eec62f08dc5deecc7d5532d6
# 41636  b866af202be0692766081310cd4085e1  d1800078046ed2e5ae1b0792b695c56e
# ...

# %%
dforder["order_delivered_carrier_date_new"]=dforder["order_approved_at"]+(dforder["order_delivered_customer_date"]-dforder["order_approved_at"])/2

# %%
#Modifica la columa order_delivered_carrier_date y arregla diff2
dforder.loc[dforder["difference_days4"]<pd.Timedelta(0),"order_delivered_carrier_date"]=dforder.loc[dforder["difference_days4"]<pd.Timedelta(0),"order_delivered_carrier_date_new"]

# %%
#vemos diferencia entre que se aprueba la compra y en la que el cliente hace la compra
dforder['difference_days1'] = dforder['order_approved_at'] - dforder['order_purchase_timestamp']
#vemos diferencia entre es llevado al flete y en la que se aprueba la compra
dforder['difference_days2'] = dforder['order_delivered_carrier_date'] - dforder['order_approved_at']
#vemos diferencia entre que el producto llega al cliente y en la que se aprueba la compra
dforder['difference_days3'] = dforder['order_delivered_customer_date'] - dforder['order_approved_at']
#vemos diferencia entre que el producto llega al cliente y en la que se lleva al flete
dforder['difference_days4'] = dforder['order_delivered_customer_date'] - dforder['order_delivered_carrier_date']
#vemos diferencia entre la estimacion de la llegada del producto al cliente y el tiempo real en que llega el producto al cliente
dforder['difference_days5'] = dforder['order_estimated_delivery_date'] - dforder['order_delivered_customer_date']

# %%
#Sin problemas diff2
dforder[dforder["difference_days2"]<pd.Timedelta(0)]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, difference_days1, difference_days2, difference_days3, difference_days4, difference_days5, order_approved_at_new, order_delivered_carrier_date_new]
# Index: []

# %%
#Sin problemas diff3
dforder[dforder["difference_days3"]<pd.Timedelta(0)]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, difference_days1, difference_days2, difference_days3, difference_days4, difference_days5, order_approved_at_new, order_delivered_carrier_date_new]
# Index: []

# %%
#Sin problemas diff4
dforder[dforder["difference_days4"]<pd.Timedelta(0)]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, difference_days1, difference_days2, difference_days3, difference_days4, difference_days5, order_approved_at_new, order_delivered_carrier_date_new]
# Index: []

# %%
dforder["order_status"].unique()
# Out:
# array(['delivered', 'invoiced', 'shipped', 'processing', 'unavailable',
#        'canceled', 'created', 'approved'], dtype=object)

# %%
dforder["order_status"].value_counts()
# Out:
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_status, dtype: int64

# %%
dforder[dforder["order_status"]=="created"]#solo fueron creados
# Out:
#                                order_id                       customer_id  \
# 7434   b5359909123fa03c50bdb0cfed07f098  438449d4af8980d107bf04571413a8e7
# 9238   dba5062fbda3af4fb6c33b1e040ca38f  964a6df3d9bdf60fe3e7b8bb69ed893a
# 21441  7a4df5d8cff4090e541401a20a22bb80  725e9c75605414b21fd8c8d5a1c2f1d6
# 55086  35de4050331c6c644cddc86f4f2d0d64  4ee64f4bfc542546f422da0aeb462853
# 58958  90ab3e7d52544ec7bc3363c82689965f  7d61b9f4f216052ba664f22e9c504ef1
#
#       order_status order_purchase_timestamp order_approved_at  \
# 7434       created      2017-12-05 01:07:52               NaT
# 9238       created      2018-02-09 17:21:04               NaT
# 21441      created      2017-11-25 11:10:33               NaT
# 55086      created      2017-12-05 01:07:58               NaT
# 58958      created      2017-11-06 13:12:34               NaT
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 7434                           NaT                           NaT
# ...

# %%
dforder[dforder["order_status"]=="unavailable"]# no disponible, solo llega  hasra aprobacion de orden
# Out:
#                                order_id                       customer_id  \
# 266    8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 586    c272bcd21c287498b4883c7512019702  9582c5bbecc65eb568e2c1d839b5cba1
# 687    37553832a3a89c9b2db59701c357ca67  7607cd563696c27ede287e515812d528
# 737    d57e15fb07fd180f06ab3926b39edcd2  470b93b3f1cde85550fc74cd3a476c78
# 1160   2f634e2cebf8c0283e7ef0989f77d217  7353b0fb8e8d9675e3a704c60ca44ebe
# ...                                 ...                               ...
# 99147  6cf5c427fb11bc5fe8abefa86aa7ba0b  91ac14a1e50bc022eeecf0c2ba37006a
# 99233  1c7c8ab324927f5b6e52338bd110bef4  95b1767df51d6fa09402267d8de314df
# 99252  aaab15da689073f8f9aa978a390a69d1  df20748206e4b865b2f14a5eabbfcf34
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
dforder[dforder["order_status"]=="unavailable"].isnull().sum()
# Out:
# order_id                              0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                     0
# order_delivered_carrier_date        609
# order_delivered_customer_date       609
# order_estimated_delivery_date         0
# difference_days1                      0
# difference_days2                    609
# difference_days3                    609
# difference_days4                    609
# difference_days5                    609
# order_approved_at_new               609
# order_delivered_carrier_date_new    609
# dtype: int64

# %%
dforder[dforder["order_status"]=="approved"]# solo han sido aprobados
# Out:
#                                order_id                       customer_id  \
# 44897  a2e4c44360b4a57bdff22f3a4630c173  8886130db0ea6e9e70ba0b03d7c0d286
# 88457  132f1e724165a07f6362532bfb97486e  b2191912d8ad6eac2e4dc3b6e1459515
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 44897     approved      2017-02-06 20:18:17 2017-02-06 20:30:19
# 88457     approved      2017-04-25 01:25:34 2017-04-30 20:32:41
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 44897                          NaT                           NaT
# 88457                          NaT                           NaT
#
#       order_estimated_delivery_date difference_days1 difference_days2  \
# 44897                    2017-03-01  0 days 00:12:02              NaT
# 88457                    2017-05-22  5 days 19:07:07              NaT
#
#       difference_days3 difference_days4 difference_days5  \
# 44897              NaT              NaT              NaT
# ...

# %%
dforder[dforder["order_status"]=="invoiced"]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 455    38b7efdf33dd5561f4f5d4f6e07b0414  021e84751ba0ead75b6d314a6ead88d9
# 1833   51b0dccc8596ce37a930dff2d63a10a2  31bf1057b00f14804278590bbac18b1b
# 2116   5504eaa5a86eb25fa666cf2e6b96c701  a30be38e1ed0ffb39b318bf1d15e98d9
# ...                                 ...                               ...
# 98414  41ad2ae32ee66c07ef3b0301ba02ad27  5c7f8d14a0a12198d1d07167d7d343b3
# 98624  9ffb325177b96c422447e3b9ee9a6270  e4079117ea0dc8bc27274e34c4796515
# 98845  021dac6e3120485db6a77474aa21b979  c40f7f00e91eb8a0da1e58484380a796
# 99031  c526fe83c01c48066394ff5d81f9ab9a  6c678c38f3a0874b7bfeeb2d5fb22876
# 99066  46bdec7cc92d926500bee756ee1df6dc  0cfcefc0ed0af6a2e601540feeac24e7
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
dforder[dforder["order_status"]=="invoiced"].isnull().sum()#aun no llega al transportador
# Out:
# order_id                              0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                     0
# order_delivered_carrier_date        314
# order_delivered_customer_date       314
# order_estimated_delivery_date         0
# difference_days1                      0
# difference_days2                    314
# difference_days3                    314
# difference_days4                    314
# difference_days5                    314
# order_approved_at_new               314
# order_delivered_carrier_date_new    314
# dtype: int64

# %%
dforder[dforder["order_status"]=="processing"]#aun no llega al transportador
# Out:
#                                order_id                       customer_id  \
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 324    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# 741    6a6c7d523fd59eb5bbefc007331af717  d954782ec6c0e911292c8a80757ef28d
# 1192   745e1d4a7f8c4b548881788d4113bb1d  7198d7088442e4ddfe553353d8ddc957
# 1516   1d52ba7197c7acebbb4f826f6585536f  c9c7fe860d602373a9e93f8bfe9d877a
# ...                                 ...                               ...
# 97400  dcdfc540e42725663242bb884c28f0a6  38972104038aa68fcc61277dbf6e7ca9
# 97666  e471815e7114cdb474064f7dbb1a8b67  092c9316ae71b2fe43e526043f351967
# 98089  10951d02d64917a34959abeb8130601e  3e6754e591ff3568ccc5bf69a649918c
# 99140  aea0db338150b526dde24f6fd953a5ed  379a02efdc6a56bd27f99b95fc2f6c06
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
dforder[dforder["order_status"]=="processing"].isnull().sum()
# Out:
# order_id                              0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                     0
# order_delivered_carrier_date        301
# order_delivered_customer_date       301
# order_estimated_delivery_date         0
# difference_days1                      0
# difference_days2                    301
# difference_days3                    301
# difference_days4                    301
# difference_days5                    301
# order_approved_at_new               301
# order_delivered_carrier_date_new    301
# dtype: int64

# %%
dforder[dforder["order_status"]=="shipped"]# aun no llega  al comprador
# Out:
#                                order_id                       customer_id  \
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# 162    36530871a5e80138db53bcfd8a104d90  4dafe3c841d2d6cc8a8b6d25b35704b9
# 231    4d630f57194f5aba1a3d12ce23e71cd9  6d491c9fe2f04f6e2af6ec033cd8907c
# 299    3b4ad687e7e5190db827e1ae5a8989dd  1a87b8517b7d31373b50396eb15cb445
# ...                                 ...                               ...
# 98534  a59ef0abffbef8ddaae23600b6ee6604  49e64271fb8eeb19851dc7e850e92204
# 98779  dab8a6c6bd6ec448df5b3a6b6cb887bc  394653a10cab83cad40d7e2713f3ab89
# 98932  492aed3c33bac22a8e04138319829283  58466c1166c377a56f6b2ae0d93ffbc0
# 99113  274a7f7e4f1c17b7434a830e9b8759b1  670af30ca5b8c20878fecdafa5ee01b9
# 99181  636cdd02667dc8d76d9296bf20a6890a  c162256b133c76f79181ce61d66545db
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
dforder[dforder["order_status"]=="shipped"].isnull().sum()
# Out:
# order_id                               0
# customer_id                            0
# order_status                           0
# order_purchase_timestamp               0
# order_approved_at                      0
# order_delivered_carrier_date           9
# order_delivered_customer_date       1107
# order_estimated_delivery_date          0
# difference_days1                       0
# difference_days2                       9
# difference_days3                    1107
# difference_days4                    1107
# difference_days5                    1107
# order_approved_at_new                  0
# order_delivered_carrier_date_new    1107
# dtype: int64

# %%
dforder[dforder["order_status"]=="delivered"]
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
dforder[dforder["order_status"]=="delivered"].isnull().sum()
# Out:
# order_id                             0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_approved_at                   14
# order_delivered_carrier_date         2
# order_delivered_customer_date        8
# order_estimated_delivery_date        0
# difference_days1                    14
# difference_days2                    16
# difference_days3                    22
# difference_days4                     9
# difference_days5                     8
# order_approved_at_new                2
# order_delivered_carrier_date_new    22
# dtype: int64

# %%
#Presenta vacios no completables
dforder[(dforder["order_status"]=="delivered") & (dforder["order_delivered_customer_date"].isnull())]
# Out:
#                                order_id                       customer_id  \
# 3002   2d1e2d5bf4dc7227b3bfebb81328c15f  ec05a6d8558c6455f0cbbd8a420ad34f
# 20618  f5dd62b788049ad9fc0526e3ad11a097  5e89028e024b381dc84a13a3570decb4
# 43834  2ebdfc4f15f23b91474edf87475f108e  29f0540231702fda0cfdee0a310f11aa
# 79263  e69f75a717d64fc5ecdfae42b2e8e086  cfda40ca8dd0a5d486a9635b611b398a
# 82868  0d3268bad9b086af767785e3f0fc0133  4f1d63d35fb7c8999853b2699f5c7649
# 92643  2d858f451373b04fb5c984a1cc2defaf  e08caf668d499a6d643dafd7c5cc498a
# 97647  ab7c89dc1bf4a1ead9d6ec1ec8968a84  dd1b84a7286eb4524d52af4256c0ba24
# 98038  20edc82cf5400ce95e1afacc25798b31  28c37425f1127d887d7337f284080a0f
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 3002     delivered      2017-11-28 17:44:07 2017-11-28 17:56:40
# 20618    delivered      2018-06-20 06:58:43 2018-06-20 07:19:05
# 43834    delivered      2018-07-01 17:05:11 2018-07-01 17:15:12
# ...

# %%
#Presenta un vacio completable
dforder[(dforder["order_status"]=="delivered") & (dforder["order_delivered_carrier_date"].isnull())]
# Out:
#                                order_id                       customer_id  \
# 73222  2aa91108853cecb43c84a5dc5b277475  afeb16c7f46396c0ed54acb45ccaaa40
# 92643  2d858f451373b04fb5c984a1cc2defaf  e08caf668d499a6d643dafd7c5cc498a
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 73222    delivered      2017-09-29 08:52:58 2017-09-29 09:07:16
# 92643    delivered      2017-05-25 23:22:43 2017-05-25 23:30:16
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 73222                          NaT           2017-11-20 19:44:47
# 92643                          NaT                           NaT
#
#       order_estimated_delivery_date difference_days1 difference_days2  \
# 73222                    2017-11-14  0 days 00:14:18              NaT
# 92643                    2017-06-23  0 days 00:07:33              NaT
#
#       difference_days3 difference_days4  difference_days5  \
# 73222 52 days 10:37:31              NaT -7 days +04:15:13
# ...

# %%
#Completando ordeer_carrier_data vacio
dforder["order_delivered_carrier_date_new"]=dforder["order_approved_at"]+(dforder["order_delivered_customer_date"]-dforder["order_approved_at"])/2
dforder.loc[(dforder["order_status"]=="delivered") & (dforder["order_delivered_carrier_date"].isnull()),"order_delivered_carrier_date"]=dforder.loc[(dforder["order_status"]=="delivered") & (dforder["order_delivered_carrier_date"].isnull()),"order_delivered_carrier_date_new"]

# %%
#nose puede completar
dforder[(dforder["order_status"]=="delivered") & (dforder["order_delivered_carrier_date"].isnull())]
# Out:
#                                order_id                       customer_id  \
# 92643  2d858f451373b04fb5c984a1cc2defaf  e08caf668d499a6d643dafd7c5cc498a
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 92643    delivered      2017-05-25 23:22:43 2017-05-25 23:30:16
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 92643                          NaT                           NaT
#
#       order_estimated_delivery_date difference_days1 difference_days2  \
# 92643                    2017-06-23  0 days 00:07:33              NaT
#
#       difference_days3 difference_days4 difference_days5  \
# 92643              NaT              NaT              NaT
#
#       order_approved_at_new order_delivered_carrier_date_new
# 92643                   NaT                              NaT

# %%
#cambiando un registro de delivered  a aproved
dforder.loc[(dforder["order_status"]=="delivered") & (dforder["order_delivered_carrier_date"].isnull()),"order_status"]="approved"

# %%
#presenta vacios completables en order_aprroved_at
dforder[(dforder["order_status"]=="delivered") & (dforder["order_approved_at"].isnull())]
# Out:
#                                order_id                       customer_id  \
# 5323   e04abd8149ef81b95221e88f6ed9ab6a  2127dc6603ac33544953ef05ec155771
# 16567  8a9adc69528e1001fc68dd0aaebbb54a  4c1ccc74e00993733742a3c786dc3c1f
# 19031  7013bcfc1c97fe719a7b5e05e61c12db  2941af76d38100e0f8740a374f1a5dc3
# 22663  5cf925b116421afa85ee25e99b4c34fb  29c35fc91fc13fb5073c8f30505d860d
# 23156  12a95a3c06dbaec84bcfb0e2da5d228a  1e101e0daffaddce8159d25a8e53f2b2
# 26800  c1d4211b3dae76144deccd6c74144a88  684cb238dc5b5d6366244e0e0776b450
# 38290  d69e5d356402adc8cf17e08b5033acfb  68d081753ad4fe22fc4d410a9eb1ca01
# 39334  d77031d6a3c8a52f019764e68f211c69  0bf35cac6cc7327065da879e2d90fae8
# 48401  7002a78c79c519ac54022d4f8a65e6e8  d5de688c321096d15508faae67a27051
# 61743  2eecb0d85f281280f79fa00f9cec1a95  a3d3c38e58b9d2dfb9207cab690b6310
# 63052  51eb2eebd5d76a24625b31c33dd41449  07a2a7e0f63fd8cb757ed77d4245623c
# 67697  88083e8f64d95b932164187484d90212  f67cd1a215aae2a1074638bbd35a223a
# ...

# %%
#Modifica la columna order_approved_at para llenar sus vacios
dforder["order_approved_at_new"]=dforder["order_purchase_timestamp"]+(dforder["order_delivered_carrier_date"]-dforder["order_purchase_timestamp"])/2
dforder.loc[(dforder["order_status"]=="delivered") & (dforder["order_approved_at"].isnull()),"order_approved_at"]=dforder.loc[(dforder["order_status"]=="delivered") & (dforder["order_approved_at"].isnull()),"order_approved_at_new"]

# %%
dforder[(dforder["order_status"]=="delivered")&(dforder["order_delivered_customer_date"].isnull())]
# Out:
#                                order_id                       customer_id  \
# 3002   2d1e2d5bf4dc7227b3bfebb81328c15f  ec05a6d8558c6455f0cbbd8a420ad34f
# 20618  f5dd62b788049ad9fc0526e3ad11a097  5e89028e024b381dc84a13a3570decb4
# 43834  2ebdfc4f15f23b91474edf87475f108e  29f0540231702fda0cfdee0a310f11aa
# 79263  e69f75a717d64fc5ecdfae42b2e8e086  cfda40ca8dd0a5d486a9635b611b398a
# 82868  0d3268bad9b086af767785e3f0fc0133  4f1d63d35fb7c8999853b2699f5c7649
# 97647  ab7c89dc1bf4a1ead9d6ec1ec8968a84  dd1b84a7286eb4524d52af4256c0ba24
# 98038  20edc82cf5400ce95e1afacc25798b31  28c37425f1127d887d7337f284080a0f
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 3002     delivered      2017-11-28 17:44:07 2017-11-28 17:56:40
# 20618    delivered      2018-06-20 06:58:43 2018-06-20 07:19:05
# 43834    delivered      2018-07-01 17:05:11 2018-07-01 17:15:12
# 79263    delivered      2018-07-01 22:05:55 2018-07-01 22:15:14
# ...

# %%
dforder[dforder["order_status"]=="delivered"].isnull().sum()
# Out:
# order_id                             0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_approved_at                    0
# order_delivered_carrier_date         0
# order_delivered_customer_date        7
# order_estimated_delivery_date        0
# difference_days1                    14
# difference_days2                    15
# difference_days3                    21
# difference_days4                     8
# difference_days5                     7
# order_approved_at_new                0
# order_delivered_carrier_date_new    21
# dtype: int64

# %%
dforder["order_status"].unique()
# Out:
# array(['delivered', 'invoiced', 'shipped', 'processing', 'unavailable',
#        'canceled', 'created', 'approved'], dtype=object)

# %%
#Cmabiando order status de delivered a shipped cuadno presenta vacios en order_delivered_customer_dat
dforder.loc[(dforder["order_status"]=="delivered")&(dforder["order_delivered_customer_date"].isnull()),"order_status"]="shipped"

# %%
dforder[dforder["order_status"]=="delivered"].isnull().sum()
# Out:
# order_id                             0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_approved_at                    0
# order_delivered_carrier_date         0
# order_delivered_customer_date        0
# order_estimated_delivery_date        0
# difference_days1                    14
# difference_days2                    15
# difference_days3                    14
# difference_days4                     1
# difference_days5                     0
# order_approved_at_new                0
# order_delivered_carrier_date_new    14
# dtype: int64

# %%
dforder["order_status"].value_counts()
# Out:
# delivered      96470
# shipped         1114
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           3
# Name: order_status, dtype: int64

# %%
dforder[dforder["order_status"]=="canceled"]
# Out:
#                                order_id                       customer_id  \
# 397    1b9ecfe83cdc259250e1a8aca174f0ad  6d6b50b66d79f80827b6d96751528d30
# 613    714fb133a6730ab81fa1d3c1b2007291  e3fe72696c4713d64d3c10afe71e75ed
# 1058   3a129877493c8189c59c60eb71d97c29  0913cdce793684e52bbfac69d87e91fd
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# ...                                 ...                               ...
# 98791  b159d0ce7cd881052da94fa165617b05  e0c3bc5ce0836b975d6b2a8ce7bb0e3e
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99143  6560fb10610771449cb0463c5ba12199  0d07d0a588caf93cc66b7a8aff86d2fe
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
dforder[dforder["order_status"]=="canceled"].isnull().sum()
# Out:
# order_id                              0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                   141
# order_delivered_carrier_date        550
# order_delivered_customer_date       619
# order_estimated_delivery_date         0
# difference_days1                    141
# difference_days2                    550
# difference_days3                    619
# difference_days4                    619
# difference_days5                    619
# order_approved_at_new               550
# order_delivered_carrier_date_new    619
# dtype: int64

# %%
#Todo correcto
dforder.loc[(dforder["order_status"]=="canceled") & (dforder["order_delivered_customer_date"].notnull()),:]
# Out:
#                                order_id                       customer_id  \
# 2921   1950d777989f6a877539f53795b4c3c3  1bccb206de9f0f25adc6871a1bcf77b2
# 8791   dabf2b0e35b423f94618bf965fcb7514  5cdec0bb8cbdf53ffc8fdc212cd247c6
# 58266  770d331c84e5b214bd9dc70a10b829d0  6c57e6119369185e575b36712766b0ef
# 59332  8beb59392e21af5eb9547ae1a9938d06  bf609b5741f71697f65ce3852c5d2623
# 92636  65d1e226dfaeb8cdc42f665422522d14  70fc57eeae292675927697fe03ad3ff5
# 94399  2c45c33d2f9cb8ff8b1c86cc28c11c30  de4caa97afa80c8eeac2ff4c8da5b72e
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 2921      canceled      2018-02-19 19:48:52 2018-02-19 20:56:05
# 8791      canceled      2016-10-09 00:56:52 2016-10-09 13:36:58
# 58266     canceled      2016-10-07 14:52:30 2016-10-07 15:07:10
# 59332     canceled      2016-10-08 20:17:50 2016-10-09 14:34:30
# 92636     canceled      2016-10-03 21:01:41 2016-10-04 10:18:57
# ...

# %%
#nada que arreglar
dforder.loc[(dforder["order_status"]=="canceled") & (dforder["order_delivered_carrier_date"].notnull()) & (dforder["order_approved_at"].isnull()),:]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, difference_days1, difference_days2, difference_days3, difference_days4, difference_days5, order_approved_at_new, order_delivered_carrier_date_new]
# Index: []

# %%
#nada que arreglar
dforder.loc[(dforder["order_status"]=="canceled") & (dforder["order_delivered_carrier_date"].notnull())& (dforder["order_purchase_timestamp"].isnull()),:]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, difference_days1, difference_days2, difference_days3, difference_days4, difference_days5, order_approved_at_new, order_delivered_carrier_date_new]
# Index: []

# %%
#Nada que arreglar
dforder.loc[(dforder["order_status"]=="canceled") & (dforder["order_approved_at"].notnull()) & (dforder["order_purchase_timestamp"].isnull()),:]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, difference_days1, difference_days2, difference_days3, difference_days4, difference_days5, order_approved_at_new, order_delivered_carrier_date_new]
# Index: []

# %%
dforder[dforder["order_status"]=="canceled"].isnull().sum()
# Out:
# order_id                              0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                   141
# order_delivered_carrier_date        550
# order_delivered_customer_date       619
# order_estimated_delivery_date         0
# difference_days1                    141
# difference_days2                    550
# difference_days3                    619
# difference_days4                    619
# difference_days5                    619
# order_approved_at_new               550
# order_delivered_carrier_date_new    619
# dtype: int64

# %%
dforder.drop(columns=["difference_days1","difference_days2","difference_days3","difference_days4","difference_days5","order_approved_at_new","order_delivered_carrier_date_new"],inplace=True)

# %%
#unionc con el dataframe obtenido en el ETL de dfpayments
dforder=pd.merge(left=dforder,right=dftotalordercost,on="order_id",how="outer")

# %%
dforder.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
dforder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99295 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97650 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
#  8   TOTAL_ORDER_COST               99440 non-null  float64
# dtypes: datetime64[ns](5), float64(1), object(3)
# memory usage: 7.6+ MB

# %%
dforder.to_csv("datasetsout/olist_orders_dataset.csv")

# %% [markdown]
# ## ETL olist_sellers_dataset

# %%
dfsellers=df10

# %%
dfsellers.head()
# Out:
#                           seller_id seller_zip_code_prefix        seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                  13023           campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                  13844         mogi guacu
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                  20031     rio de janeiro
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                  04195          sao paulo
# 4  51a04a8a6bdcb23deccc82b0b80742cf                  12914  braganca paulista
#
#   seller_state
# 0           SP
# 1           SP
# 2           RJ
# 3           SP
# 4           SP

# %%
dfsellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   object
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: object(4)
# memory usage: 96.8+ KB

# %%
dfsellers.drop(columns=["seller_city","seller_state"],axis=1,inplace=True)

# %%
dfsellers['seller_zip_code_prefix'] = dfsellers['seller_zip_code_prefix'].astype('string')

# %%
dfsellers.head()
# Out:
#                           seller_id seller_zip_code_prefix
# 0  3442f8959a84dea7ee197c632cb2df15                  13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                  13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                  20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                  04195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                  12914

# %%
dfsellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   string
# dtypes: object(1), string(1)
# memory usage: 48.5+ KB

# %%
dfsellers.to_csv("datasetsout/olist_sellers_dataset.csv")

# %% [markdown]
# ## ETL olist_products_dataset.csv

# %%
dfproducts=df9

# %%
dfproducts.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
dfproducts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
dfproducts["product_photos_qty"].fillna(0.0,inplace=True)

# %%
dfproducts["product_photos_qty"] = dfproducts["product_photos_qty"] .astype("int")

# %%
dfproducts.drop(columns=["product_name_lenght","product_description_lenght","product_weight_g","product_length_cm","product_height_cm","product_width_cm"],axis=1,inplace=True)

# %%
dfproducts.head()
# Out:
#                          product_id  product_category_name  product_photos_qty
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria                   1
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes                   1
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer                   1
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes                   1
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas                   4

# %%
dfproducts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             32951 non-null  object
#  1   product_category_name  32341 non-null  object
#  2   product_photos_qty     32951 non-null  int32
# dtypes: int32(1), object(2)
# memory usage: 643.7+ KB

# %%
dfproducts.to_csv("datasetsout/olist_products_dataset.csv")

# %% [markdown]
# ## ETL product_category_name_translation.csv

# %%
dfproductcategory=df11

# %%
dfproductcategory.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
dfproductcategory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
#agregnado filas con category name que se encuentra en productos pero no en 
dfproductcategory=dfproductcategory.append({"product_category_name" : "pc_gamer" , "product_category_name_english" : "pc_gamer"} , ignore_index=True)
dfproductcategory=dfproductcategory.append({"product_category_name" : "portateis_cozinha_e_preparadores_de_alimentos" , "product_category_name_english" : "kitchen and food preparation racks"} , ignore_index=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7812\3145378947.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfproductcategory=dfproductcategory.append({"product_category_name" : "pc_gamer" , "product_category_name_english" : "pc_gamer"} , ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7812\3145378947.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfproductcategory=dfproductcategory.append({"product_category_name" : "portateis_cozinha_e_preparadores_de_alimentos" , "product_category_name_english" : "kitchen and food preparation racks"} , ignore_index=True)

# %%
dfproductcategory.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
dfproductcategory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          73 non-null     object
#  1   product_category_name_english  73 non-null     object
# dtypes: object(2)
# memory usage: 1.3+ KB

# %%
dfproductcategory.to_csv("datasetsout/product_category_name_translation.csv")
