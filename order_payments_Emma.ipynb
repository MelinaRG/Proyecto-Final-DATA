# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ordpay = pd.read_csv('./datasets/olist_order_payments_dataset.csv')

# %%
#El dataset contiene 5 columnas con 103.886 filas.
ordpay.shape
# Out:
# (103886, 5)

# %%
#Las columnas poseen información relacionada al pago, pagos parciales, medio de pago, cuotas e importe total.
ordpay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
#Confirmo la inexistencia de valores nulos.
ordpay.isnull().sum().sort_values()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
#Verifico que no hay valores duplicados.
ordpay.duplicated().sum()
# Out:
# 0

# %%
#Anáisis preliminar de los datos numéricos de 3 columnas. Vemos valores extremos, rango de datos y en especial outliers (relación de mediana y media).
ordpay.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
ordpay.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
#Grafico la distribución de los datos en pares ordenados.
plt.figure(figsize=(10,10))
sns.pairplot(ordpay)

# %%
plt.figure(figsize=(5,5))
plt.title("Importe de la orden")
sns.histplot(ordpay['payment_value'])
# Out:
# <AxesSubplot:title={'center':'Importe de la orden'}, xlabel='payment_value', ylabel='Count'>

# %%
plt.figure(figsize=(5,5))
plt.title("Importe de la orden")
sns.scatterplot(ordpay['payment_value'])
# Out:
# <AxesSubplot:title={'center':'Importe de la orden'}, ylabel='payment_value'>

# %%
plt.figure(figsize=(5,5))
plt.title("Cantidad de pagos anticipados")
sns.histplot(ordpay['payment_installments'])

# %%
plt.figure(figsize=(5,5))
plt.title("Cantidad de pagos anticipados")
sns.scatterplot(ordpay['payment_installments'])

# %%
plt.figure(figsize=(5,5))
plt.title("Cantidad de cuotas")
sns.histplot(ordpay['payment_installments'])
# Out:
# <AxesSubplot:title={'center':'Cantidad de cuotas'}, xlabel='payment_installments', ylabel='Count'>

# %%
plt.figure(figsize=(5,5))
plt.title("Cantidad de cuotas")
sns.scatterplot(ordpay['payment_installments'])
# Out:
# <AxesSubplot:xlabel='payment_value'>
